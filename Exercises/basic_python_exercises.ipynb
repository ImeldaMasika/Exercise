# %% [markdown]
# <a href="https://colab.research.google.com/github/ImeldaMasika/Exercise/blob/main/Exercises/basic_python_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python
#
# This notebook contains basic programming exercises.
# Try to solve each problem in the code cells below.

# %% [markdown]
# ## Exercise 1: Print Hello
# Write a program to print 'Hello, World!'

# %%
# Your code here
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## Exercise 2: Addition
# Take two numbers and print their sum.

# %%
# Example:
a = 5
b = 3
# Your code here
print(a+b)
# Out:
# 8

# %% [markdown]
# ## Exercise 3: Subtraction
# Take two numbers, subtract them and print the result.

# %%
# Example:
a = 9
b = 2
# Your code here
print(a-b)
# Out:
# 7

# %% [markdown]
# ## Exercise 4: Swap
# Swap two numbers without using a third variable.

# %%
# Example:
a = 8
b = 5
# Your code here
a,b=b,a
print(a,b)
# Out:
# 5 8

# %% [markdown]
# ## Exercise 5: Division
# Read two numbers from keyboard, divide them and print the result.

# %%
# Example:
a = int (input())
b = int (input())
# Your code here
print(a/b)
# Out:
# 10
# 5
# 2.0

# %% [markdown]
# ## Exercise 6: Conversion
#
# Read temparature in Celsius and convert it into Fahrenheit.
#
# For example:
#
# Fahrenheit = (Celsius * 1.8)+32

# %%
#Example:

c = float (input())

# Your code here
f=(c*1.8)+32
print(f)
# Out:
# 25
# 77.0

# %% [markdown]
# ## Exercise 7: Square root
#
# Read a number from keyboard, calculate the square root and display it.

# %%
# Your code here
import math

n = float(input())

sqrt_value = math.sqrt(n)

print(sqrt_value)
# Out:
# 10
# 3.1622776601683795
